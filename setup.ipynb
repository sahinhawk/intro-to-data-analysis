# %% [markdown]
# Make your own brand of cereal and join it to the pre-existing cereal DataFrame.

# %%
import pandas as pd
cereals = pd.read_csv('cereals.csv')
cereals.loc[77] = ['Great Oats','R','C',85,5,1,222,1,23,5,21,32,2,1,0.4,95.445019]
cereals
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C      70.0        4    1     130   10.0
# 1           100% Natural Bran   Q    C     120.0        3    5      15    2.0
# 2                    All-Bran   K    C      70.0        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C      50.0        4    0     140   14.0
# 4              Almond Delight   R    C     110.0        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 73                       Trix   G    C     110.0        1    1     140    0.0
# 74                 Wheat Chex   R    C     100.0        3    1     230    3.0
# 75                   Wheaties   G    C     100.0        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C     110.0        2    1     200    1.0
# 77                 Great Oats   R    C      85.0        5    1     222    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0     6.0     280        25      3     1.0  0.33  68.402973
# 1     8.0     8.0     135         0      3     1.0  1.00  33.983679
# 2     7.0     5.0     320        25      3     1.0  0.33  59.425505
# 3     8.0     0.0     330        25      3     1.0  0.50  93.704912
# 4    14.0     8.0      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 73   13.0    12.0      25        25      2     1.0  1.00  27.753301
# 74   17.0     3.0     115        25      1     1.0  0.67  49.787445
# 75   17.0     3.0     110        25      1     1.0  1.00  51.592193
# 76   16.0     NaN      60        25      1     1.0  0.75  36.187559
# 77   23.0     5.0      21        32      2     1.0  0.40  95.445019
#
# [78 rows x 16 columns]

# %% [markdown]
# Make two more brands of cereal, and load them into their own DataFrame

# %%
cherry_bites = {
"name" : 'Cherry Bites',
"mfr" : 'N',
"type" : 'C',
"calories" : 150,
"protein" : 5,
"fat" : 2,
"sodium" : 212,
"fiber" : 12,
"carbo" : 23,
"sugars" : 8,
"potass" : 90,
"vitamins" : 25,
"shelf" : 3,
"weight" : 1,
"cups" : 0.45,
"rating" : 92.562198
}

gromit_bites = {
"name" : 'Gromit Bites',
"mfr" : 'N',
"type" : 'C',
"calories" : 222,
"protein" : 3,
"fat" : 3,
"sodium" : 200,
"fiber" : 10,
"carbo" : 24,
"sugars" : 4,
"potass" : 120,
"vitamins" : 30,
"shelf" : 3,
"weight" : 1,
"cups" : 0.45,
"rating" : 80.482943
}
new_df = pd.DataFrame([cherry_bites, gromit_bites])
new_df
# Out:
#            name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 0  Cherry Bites   N    C       150        5    2     212     12     23
# 1  Gromit Bites   N    C       222        3    3     200     10     24
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 0       8      90        25      3       1  0.45  92.562198
# 1       4     120        30      3       1  0.45  80.482943

# %% [markdown]
# Join them to your initial cereal DataFrame.

# %%
df = pd.concat([cereals,new_df],ignore_index=True)
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C      70.0        4    1     130   10.0
# 1           100% Natural Bran   Q    C     120.0        3    5      15    2.0
# 2                    All-Bran   K    C      70.0        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C      50.0        4    0     140   14.0
# 4              Almond Delight   R    C     110.0        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 75                   Wheaties   G    C     100.0        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C     110.0        2    1     200    1.0
# 77                 Great Oats   R    C      85.0        5    1     222    1.0
# 78               Cherry Bites   N    C     150.0        5    2     212   12.0
# 79               Gromit Bites   N    C     222.0        3    3     200   10.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0     6.0     280        25      3     1.0  0.33  68.402973
# 1     8.0     8.0     135         0      3     1.0  1.00  33.983679
# 2     7.0     5.0     320        25      3     1.0  0.33  59.425505
# 3     8.0     0.0     330        25      3     1.0  0.50  93.704912
# 4    14.0     8.0      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 75   17.0     3.0     110        25      1     1.0  1.00  51.592193
# 76   16.0     NaN      60        25      1     1.0  0.75  36.187559
# 77   23.0     5.0      21        32      2     1.0  0.40  95.445019
# 78   23.0     8.0      90        25      3     1.0  0.45  92.562198
# 79   24.0     4.0     120        30      3     1.0  0.45  80.482943
#
# [80 rows x 16 columns]

# %% [markdown]
# For an extra challenge, let us imagine that the cereal data was recorded before the infamous 'Sugar Tax' that was brought into law in 2018.
# Copy the original cereal data, but reduce the sugar percentage by 20%. Store this in a separate DataFrame.

# %%
df_sugar = df.copy()

df_sugar['sugars'] = df_sugar['sugars'] * 0.8

df_sugar
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C      70.0        4    1     130   10.0
# 1           100% Natural Bran   Q    C     120.0        3    5      15    2.0
# 2                    All-Bran   K    C      70.0        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C      50.0        4    0     140   14.0
# 4              Almond Delight   R    C     110.0        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 75                   Wheaties   G    C     100.0        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C     110.0        2    1     200    1.0
# 77                 Great Oats   R    C      85.0        5    1     222    1.0
# 78               Cherry Bites   N    C     150.0        5    2     212   12.0
# 79               Gromit Bites   N    C     222.0        3    3     200   10.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0     4.8     280        25      3     1.0  0.33  68.402973
# 1     8.0     6.4     135         0      3     1.0  1.00  33.983679
# 2     7.0     4.0     320        25      3     1.0  0.33  59.425505
# 3     8.0     0.0     330        25      3     1.0  0.50  93.704912
# 4    14.0     6.4      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 75   17.0     2.4     110        25      1     1.0  1.00  51.592193
# 76   16.0     NaN      60        25      1     1.0  0.75  36.187559
# 77   23.0     4.0      21        32      2     1.0  0.40  95.445019
# 78   23.0     6.4      90        25      3     1.0  0.45  92.562198
# 79   24.0     3.2     120        30      3     1.0  0.45  80.482943
#
# [80 rows x 16 columns]
